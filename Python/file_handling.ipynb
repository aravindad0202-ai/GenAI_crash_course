# %% [markdown]
# # File Handling

# %%
file = open(r'D:\IT\AI\teaching\GenAI_module_1\Python\stub\sample_read.txt')
print(file.read()) # Read entire file
file.close()

# D:/IT/AI -> Python
# Out:
# Python is an easy and popular programming language.
# It uses clean text that looks like simple English.
# People use it for web sites, data work, and tasks

# %%
file = open(r'D:\IT\AI\teaching\GenAI_module_1\Python\stub\sample_read.txt')
print(file.readlines()) # Read entire file
file.close()
# Out:
# ['Python is an easy and popular programming language.\\n\n', 'It uses clean text that looks like simple English.\\n\n', 'People use it for web sites, data work, and tasks\\n']

# %%
file = open(r'D:\IT\AI\teaching\GenAI_module_1\Python\stub\sample_read.txt', 'a')
file.write('\nI am a python developer')
file.close()

# %% [markdown]
# # Context manager

# %%
with open(r'D:\IT\AI\teaching\GenAI_module_1\Python\stub\sample_read.txt', 'r') as files:
    print(files.read())
# Out:
# Python is an easy and popular programming language.
# It uses clean text that looks like simple English.
# People use it for web sites, data work, and tasks

# %% [markdown]
# # JSON handling

# %%
import json

with open(r'D:\IT\AI\teaching\GenAI_module_1\Python\stub\sample_read.json','r') as json_data:
    values = json.load(json_data)
    print(values)
# Out:
# {'name': 'Aravind', 'work_experience': 5, 'Company': 'TCS', 'Personal': {'age': 27, 'place': 'Cuddalore'}}

# %%
# json.loads()

dict_str = '''{
"name":"Aravind","Age":"27"}'''
print(type(dict_str))
print("-------------------------------------")
dict = json.loads(dict_str)
print(dict)
print(type(dict))
print(dict['name'])
# Out:
# <class 'str'>
# -------------------------------------
# {'name': 'Aravind', 'Age': '27'}
# <class 'dict'>
# Aravind

# %%
a='''{
  "name": "aravind",
  "age": 27
}'''
json_data = json.loads(a)
print(json_data['name'])
json_data['company'] = 'TCS'
print(json_data)
# Out:
# aravind
# {'name': 'aravind', 'age': 27, 'company': 'TCS'}

# %%
# json.dump()
a = {
    "name":"aravind",
    "age":27
}

with open(r'D:\IT\AI\teaching\GenAI_module_1\Python\stub\sample_read.json', 'w') as file:
    json.dump(a, file)

print(type(a))
data = json.dumps(a)
print(type(data))
# Out:
# <class 'dict'>
# <class 'str'>
